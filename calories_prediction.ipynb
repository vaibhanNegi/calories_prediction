# %%
import pandas as pd
import numpy as np

# %%
calories=pd.read_csv('calories.csv')
exercise=pd.read_csv('exercise.csv')

# %%
calories.head()
# Out:
#     User_ID  Calories
# 0  14733363     231.0
# 1  14861698      66.0
# 2  11179863      26.0
# 3  16180408      71.0
# 4  17771927      35.0

# %%
exercise.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8

# %%
df = exercise.merge(calories, how='inner', on='User_ID')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## univariate analysis

# %%
#sns.countplot(df['Gender'])

# %%
df.shape
# Out:
# (15000, 9)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# female    7553
# male      7447
# Name: count, dtype: int64

# %%
plt.hist(df['Age'], bins=20)
# Out:
# (array([1498., 1272., 1238., 1043.,  975.,  889.,  847.,  759.,  725.,
#          650.,  642.,  622.,  549.,  551.,  538.,  478.,  449.,  467.,
#          398.,  410.]),
#  array([20.  , 22.95, 25.9 , 28.85, 31.8 , 34.75, 37.7 , 40.65, 43.6 ,
#         46.55, 49.5 , 52.45, 55.4 , 58.35, 61.3 , 64.25, 67.2 , 70.15,
#         73.1 , 76.05, 79.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # bi or multi variate analysis

# %% [markdown]
# ### scatterplot (numerical to numerical)

# %%
df.head(1)
# Out:
#     User_ID Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363   male   68   190.0    94.0      29.0       105.0       40.8
#
#    Calories
# 0     231.0

# %%
sns.scatterplot(x='Age', y='Height', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.scatterplot(x='Calories', y='Height', data=df)
# Out:
# <Axes: xlabel='Calories', ylabel='Height'>

# %%
sns.scatterplot(x='Age', y='Duration', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Duration'>

# %%
sns.scatterplot(x='Duration', y='Calories', data=df)
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %% [markdown]
# ### bar plot (numerical - categorical)

# %%
sns.barplot(x='Age', y='Calories', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Calories'>

# %%
#sns.barplot(x='Gender', y='Age', data=df)

# %%
#sns.barplot(x='Gender', y='Duration', data=df)

# %% [markdown]
# ### box plot (numerical to categorical)

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %% [markdown]
# ### distplot (numerical-categorical)

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\birendra singh e\AppData\Local\Temp\ipykernel_13116\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#df['gender_binary'] = df['Gender'].replace({'male': 0, 'female': 1})

# %%
df['Gender'] = df['Gender'].map({'male':1,'female':0})
df.head(1)
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363       1   68   190.0    94.0      29.0       105.0       40.8
#
#    Calories
# 0     231.0

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363       1   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698       0   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863       1   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408       0   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927       0   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
#sns.distplot(df[df['Gender']=='Male']['Age'])
# in this it showing nothing because male is string nd we hve to change the gender to 0,1 then only we will get the nswer plot

# %% [markdown]
# ### lineplot (numerical-numerical)

# %%
sns.lineplot(x='Age',y='Calories',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Calories'>

# %% [markdown]
# ## train test split

# %%
x=df.drop(['User_ID','Calories'],axis=1)
y=df['Calories']

# %%
x.shape
# Out:
# (15000, 7)

# %%
y.shape
# Out:
# (15000,)

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363       1   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698       0   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863       1   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408       0   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927       0   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (12000, 7)

# %%
x_test.shape
# Out:
# (3000, 7)

# %%
y_train.shape
# Out:
# (12000,)

# %%
y_test.shape
# Out:
# (3000,)

# %% [markdown]
# ## training model

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %%
models ={
    'Linear Regression': LinearRegression(),
    'Ridge': Ridge(),
    'Lasso': Lasso(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor()
}

# %%
for name,mod in models.items():
    mod.fit(x_train,y_train)
    y_pred = mod.predict(x_test)
    
    print(f"{name} MSE: {mean_squared_error(y_test,y_pred)},score: {r2_score(y_test,y_pred)}")
    
    
    # select the algorithm which will have MSE lowest and score highest
    # in this case Random Forest is the best algorithm for this dataset
# Out:
# Linear Regression MSE: 131.99574575081704,score: 0.9672937151257295
# Ridge MSE: 131.9962590313935,score: 0.9672935879435945
# Lasso MSE: 143.8268946117507,score: 0.9643621590908397
# Decision Tree MSE: 27.476,score: 0.9931919178296708
# Random Forest MSE: 7.0926654666666655,score: 0.9982425589858887

# %% [markdown]
# ## selecting random forest

# %%
rfr = RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred = rfr.predict(x_test)

# %%
import pickle
pickle.dump(rfr,open('rfr.pkl','wb'))

# %%
x_train.to_csv('x_train.csv')
